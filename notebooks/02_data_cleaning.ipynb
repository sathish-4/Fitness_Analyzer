# %%
import pandas as pd
import numpy as np

activity=pd.read_csv('../data/dailyActivity_merged.csv')
sleep=pd.read_csv('../data/sleepDay_merged.csv')

print("activity  :", activity.shape)
print("sleep  :", sleep.shape)
print("Data loaded sucessfully!")
# Out:
# activity  : (940, 15)
# sleep  : (413, 6)
# Data loaded sucessfully!

# %%
print(activity['ActivityDate'].dtype)
print(activity['ActivityDate'].head())
# Out:
# str
# 0    4/12/2016
# 1    4/13/2016
# 2    4/14/2016
# 3    4/15/2016
# 4    4/16/2016
# Name: ActivityDate, dtype: str

# %%
activity['ActivityDate'] = pd.to_datetime(activity['ActivityDate'])

print(activity['ActivityDate'].dtype)
print(activity['ActivityDate'].head())b
# Out:
# datetime64[us]
# 0   2016-04-12
# 1   2016-04-13
# 2   2016-04-14
# 3   2016-04-15
# 4   2016-04-16
# Name: ActivityDate, dtype: datetime64[us]

# %%
print("Duplicates in activity : ",activity.duplicated().sum())
print("Duplocates in sleep : " ,sleep.duplicated().sum())
# Out:
# Duplicates in activity :  0
# Duplocates in sleep :  3

# %%
sleep = sleep.drop_duplicates()

print("Duplicated after removing duplicated : ",sleep.duplicated().sum())
print("Sleep shape after removing duplicates : ",sleep.shape)
# Out:
# Duplicated after removing duplicated :  0
# Sleep shape after removing duplicates :  (410, 6)

# %%
print("Missing values in activity : ")
print(activity.isnull().sum())

print("Missing values in sleep : ")
print(sleep.isnull().sum())
# Out:
# Missing values in activity :
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64
# Missing values in sleep :
# Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# Date                  0
# dtype: int64

# %%
activity['DayOfWeek']=activity['ActivityDate'].dt.day_name()
activity['Month']=activity['ActivityDate'].dt.month_name()
activity['DayNum']=activity['ActivityDate'].dt.day

activity[['ActivityDate', 'DayOfWeek', 'Month','DayNum']].head()
# Out:
#   ActivityDate  DayOfWeek  Month  DayNum
# 0   2016-04-12    Tuesday  April      12
# 1   2016-04-13  Wednesday  April      13
# 2   2016-04-14   Thursday  April      14
# 3   2016-04-15     Friday  April      15
# 4   2016-04-16   Saturday  April      16

# %%
df.to_csv('../data.../merged_data.csv' ,index=False)

print("Saved")
print("Phase 2 completed ")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.to_csv('../data.../merged_data.csv' ,index=False)
#       2
#       3 print("Saved")
#       4 print("Phase 2 completed ")
#
# NameError: name 'df' is not defined

# %%
# Fix sleep date format first
sleep['SleepDay'] = pd.to_datetime(sleep['SleepDay'])

# Rename to match activity
sleep = sleep.rename(columns={'SleepDay': 'ActivityDate'})

# Now merge
df = pd.merge(activity, sleep,
              on=['Id', 'ActivityDate'],
              how='left')

# Save
df.to_csv('../data/merged_data.csv', index=False)
print("Merged shape:", df.shape)
print("Phase 2 Complete!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...

# %%
print("Activity date type:", activity['ActivityDate'].dtype)
print("Sleep date type:", sleep['SleepDay'].dtype)
# Out:
# Activity date type: datetime64[us]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
# Fix sleep date format
sleep['SleepDay'] = pd.to_datetime(sleep['SleepDay'])

# Check both are now datetime
print("Activity date type:", activity['ActivityDate'].dtype)
print("Sleep date type:", sleep['SleepDay'].dtype)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# ...

# %%
print(sleep.columns.tolist())
# Out:
# ['Id', 'ActivityDate', 'TotalSleepRecords', 'TotalMinutesAsleep', 'TotalTimeInBed', 'Date']

# %%
# Fix sleep date format
sleep['ActivityDate'] = pd.to_datetime(sleep['ActivityDate'])

# Check both are now datetime
print("Activity date type:", activity['ActivityDate'].dtype)
print("Sleep date type:", sleep['ActivityDate'].dtype)
# Out:
# Activity date type: datetime64[us]
# Sleep date type: datetime64[us]

# %%
# Merge activity and sleep together
df = pd.merge(activity, sleep,
              on=['Id', 'ActivityDate'],
              how='left')

# Save clean data
df.to_csv('../data/merged_data.csv', index=False)

print("Merged shape:", df.shape)
print("Saved!")
print("Phase 2 Complete!")
# Out:
# Merged shape: (940, 22)
# Saved!
# Phase 2 Complete!
